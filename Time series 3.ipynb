# %% [markdown]
# <a href="https://colab.research.google.com/github/Nethra07-star/PYTHON-FOR-ML/blob/main/Time%20series%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime

#create a date variable that contains the dates
dates = [datetime(2011, 1, 2),
datetime(2011, 1, 5),
datetime(2011, 1, 7),
datetime(2011, 1, 8),
datetime(2011, 1, 10),
datetime(2011, 1, 12)]

#with this date object, create a series
ts = pd.Series(np.random.randn(6), index=dates)
print("Date Index \n",ts)
# Out:
# Date Index
#  2011-01-02    0.253913
# 2011-01-05   -0.694290
# 2011-01-07   -1.395467
# 2011-01-08   -0.035293
# 2011-01-10   -2.151524
# 2011-01-12   -1.328963
# dtype: float64

# %%
print("\nDate Index alone from the series: \n",ts.index)
# Out:
# Date Index alone from the series:
#  DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
stamp=ts.index[2]
print("\nSecond index:\n", stamp)
# Out:
# Second index:
#  2011-01-07 00:00:00

# %%
#play like a ball with long-times series
longer_ts=pd.Series(np.random.randn(1000),
index=pd.date_range("2000-01-01",periods=1000))
print("\nDaterange up to 1000 days:\n",longer_ts)
# Out:
# Daterange up to 1000 days:
#  2000-01-01    0.024455
# 2000-01-02   -0.138087
# 2000-01-03   -1.052296
# 2000-01-04    0.273552
# 2000-01-05    0.114625
#                 ...
# 2002-09-22   -0.495092
# 2002-09-23    2.050792
# 2002-09-24   -1.286937
# 2002-09-25   -1.276358
# 2002-09-26   -0.354670
# Freq: D, Length: 1000, dtype: float64

# %%
print("\nDate range-2001 year:\n", longer_ts["2001"])
# Out:
# Date range-2001 year:
#  2001-01-01    0.823910
# 2001-01-02    0.112168
# 2001-01-03    0.011249
# 2001-01-04   -0.390875
# 2001-01-05   -0.219916
#                 ...
# 2001-12-27   -0.906502
# 2001-12-28   -0.315848
# 2001-12-29    0.587332
# 2001-12-30    2.569059
# 2001-12-31    0.197209
# Freq: D, Length: 365, dtype: float64

# %%
print("\nDate range-first few dates in 2000 year:\n",longer_ts["2000"].head())
# Out:
# Date range-first few dates in 2000 year:
#  2000-01-01    0.024455
# 2000-01-02   -0.138087
# 2000-01-03   -1.052296
# 2000-01-04    0.273552
# 2000-01-05    0.114625
# Freq: D, dtype: float64

# %%
print("\nDate range-first 15 dates in 02 month 2001 year:\n",longer_ts["2000-02"].head(15))
# Out:
# Date range-first 15 dates in 02 month 2001 year:
#  2000-02-01   -0.702732
# 2000-02-02    1.137017
# 2000-02-03   -0.343147
# 2000-02-04    0.835818
# 2000-02-05    0.809174
# 2000-02-06   -1.749590
# 2000-02-07   -0.423747
# 2000-02-08    1.712925
# 2000-02-09   -1.998897
# 2000-02-10   -0.210551
# 2000-02-11   -0.536835
# 2000-02-12    0.701021
# 2000-02-13    2.108706
# 2000-02-14   -1.035232
# 2000-02-15    0.493270
# Freq: D, dtype: float64

# %%
print("\nDate range-rom 26-9-2001:\n",longer_ts[datetime(2000,9,26):])
# Out:
# Date range-rom 26-9-2001:
#  2000-09-26    2.392428
# 2000-09-27    0.121793
# 2000-09-28    0.519914
# 2000-09-29   -1.128210
# 2000-09-30    0.350327
#                 ...
# 2002-09-22   -0.495092
# 2002-09-23    2.050792
# 2002-09-24   -1.286937
# 2002-09-25   -1.276358
# 2002-09-26   -0.354670
# Freq: D, Length: 731, dtype: float64

# %%
print("""\nDate range from 26-9-2001 to 25-9-
2002:\n""",longer_ts[datetime(2001,9,26):datetime(2002,9,25)])
# Out:
# Date range from 26-9-2001 to 25-9-
# 2002:
#  2001-09-26   -0.258588
# 2001-09-27    1.284881
# 2001-09-28   -0.024808
# 2001-09-29    0.226429
# 2001-09-30    2.267791
#                 ...
# 2002-09-21    0.482554
# 2002-09-22   -0.495092
# 2002-09-23    2.050792
# 2002-09-24   -1.286937
# 2002-09-25   -1.276358
# Freq: D, Length: 365, dtype: float64
