# %% [markdown]
# <a href="https://colab.research.google.com/github/Nethra07-star/PYTHON-FOR-ML/blob/main/Data%20cleaning%20and%20preperation-DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'])
columns=['one','two','three']
df=df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#            0         1         2
# a  0.742616  1.595237 -1.480440
# b       NaN       NaN       NaN
# c  2.813759  0.967897 -1.041405
# d  1.451399  0.058527  1.177089
# e       NaN       NaN       NaN
# f -1.386088 -1.796103  0.400469
#
#
# Dropped DataFrame
#            0         1         2
# a  0.742616  1.595237 -1.480440
# c  2.813759  0.967897 -1.041405
# d  1.451399  0.058527  1.177089
# f -1.386088 -1.796103  0.400469

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'])
columns=['one','two','three']
df=df.reindex(['a','b','c'])
print("Original dataFrame:\n",df)
print("\n")
print("NaN replaced with '0':\n",df)
print(df.fillna(0))
# Out:
# Original dataFrame:
#            0         1         2
# a -1.011671  0.274186 -1.869416
# b       NaN       NaN       NaN
# c  0.955996  1.309526  0.401067
#
#
# NaN replaced with '0':
#            0         1         2
# a -1.011671  0.274186 -1.869416
# b       NaN       NaN       NaN
# c  0.955996  1.309526  0.401067
#           0         1         2
# a -1.011671  0.274186 -1.869416
# b  0.000000  0.000000  0.000000
# c  0.955996  1.309526  0.401067

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],'two':[60,70,80,0,10]})
print("Original DataFrame:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original DataFrame:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("/nNaN-with True fill:\n")
print(df['one'].isnull())
# Out:
# /nNaN-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3),index=['a','c','d','f'],columns=['one','two','three'])
df=df.reindex(['a','b','c','d','e','f'])
print("\nNaN-filled with background values:\n")
print(df.fillna(method='bfill'))
# Out:
# NaN-filled with background values:
#
#         one       two     three
# a -2.281243  0.687806 -1.678054
# b -0.259062  1.265232 -1.252995
# c -0.259062  1.265232 -1.252995
# d  1.073561  0.241500 -0.701168
# e  1.064482 -0.696230 -0.269078
# f  1.064482 -0.696230 -0.269078
# /tmp/ipykernel_2318/2572233419.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
